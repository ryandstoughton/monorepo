# %%
import httpx
import json


with httpx.Client() as client:
    response = client.get("https://api.scryfall.com/bulk-data/default-cards")
    print(json.dumps(response.json(), indent=2))
# Out:
# {
#   "object": "bulk_data",
#   "id": "e2ef41e3-5778-4bc2-af3f-78eca4dd9c23",
#   "type": "default_cards",
#   "updated_at": "2025-06-24T09:13:12.597+00:00",
#   "uri": "https://api.scryfall.com/bulk-data/e2ef41e3-5778-4bc2-af3f-78eca4dd9c23",
#   "name": "Default Cards",
#   "description": "A JSON file containing every card object on Scryfall in English or the printed language if the card is only available in one language.",
#   "size": 504973344,
#   "download_uri": "https://data.scryfall.io/default-cards/default-cards-20250624091312.json",
#   "content_type": "application/json",
#   "content_encoding": "gzip"
# }
